# %% [markdown]
# <a href="https://colab.research.google.com/github/Ananya432000/python-project/blob/main/haberman_dataset_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Predicting Post-Surgery Survival of Breast Cancer Patients (Haberman Dataset)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/haberman.csv',names=['age', 'year', 'positive_nodes', 'status'])

# %%
df['status'] = df['status'].map({1: 'Survived_5_years_or_more', 2: 'Died_within_5_years'})

# %%
sns.set(style='whitegrid', palette='pastel')

# %% [markdown]
# **HISTOGRAM**

# %%
plt.figure(figsize=(15,4))
for i, col in enumerate(['age', 'year', 'positive_nodes']):
    plt.subplot(1,3,i+1)
    sns.histplot(df[col], kde=True, bins=15, color='skyblue')
    plt.title(f'Histogram of {col}')
plt.tight_layout()
plt.savefig('histograms.png')
plt.show()

# %% [markdown]
# **` Boxplot`**

# %%
plt.figure(figsize=(15,4))
for i, col in enumerate(['age', 'year', 'positive_nodes']):
    plt.subplot(1,3,i+1)
    sns.boxplot(y=df[col], color='lightgreen')
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.savefig('Boxplots.png')
plt.show()

# %% [markdown]
# **Violin Plot by Survival Status**

# %%
plt.figure(figsize=(15,4))
for i, col in enumerate(['age', 'year', 'positive_nodes']):
    plt.subplot(1,3,i+1)
    sns.violinplot(x='status', y=col, data=df, palette='muted')
    plt.title(f'{col} by Survival Status')
plt.tight_layout()
plt.savefig('violinplots.png')
plt.show()
# Out:
# /tmp/ipython-input-3940442053.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='status', y=col, data=df, palette='muted')
# /tmp/ipython-input-3940442053.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='status', y=col, data=df, palette='muted')
# /tmp/ipython-input-3940442053.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='status', y=col, data=df, palette='muted')

# %% [markdown]
# **Class-wise Histogram**

# %%
for col in ['age', 'year', 'positive_nodes']:
    plt.figure(figsize=(6,4))
    sns.histplot(data=df, x=col, hue='status', kde=True, bins=15, palette='coolwarm')
    plt.title(f'{col} Distribution by Survival Status')
    plt.savefig('histograms.png')
    plt.show()

# %% [markdown]
# **Pairplot**

# %%
sns.pairplot(df, hue='status', diag_kind='kde', palette='husl')
plt.suptitle("Pairwise Relationships between Variables", y=1.02)
plt.savefig('pairplot.png')
plt.show()

# %% [markdown]
# **Scatter Plots**

# %%
plt.subplot(1,3,1)
sns.scatterplot(x='age', y='positive_nodes', hue='status', data=df, palette='coolwarm')
plt.title('Age vs Positive Nodes')
# Out:
# Text(0.5, 1.0, 'Age vs Positive Nodes')

# %%
plt.subplot(1,3,2)
sns.scatterplot(x='year', y='positive_nodes', hue='status', data=df, palette='viridis')
plt.title('Year vs Positive Nodes')
# Out:
# Text(0.5, 1.0, 'Year vs Positive Nodes')

# %% [markdown]
# **Boxplots**

# %%
plt.figure(figsize=(15,4))
for i, col in enumerate(['age', 'year', 'positive_nodes']):
    plt.subplot(1,3,i+1)
    sns.boxplot(x='status', y=col, data=df, palette='pastel')
    plt.title(f'{col} vs Survival Status')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1732532863.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='status', y=col, data=df, palette='pastel')
# /tmp/ipython-input-1732532863.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='status', y=col, data=df, palette='pastel')
# /tmp/ipython-input-1732532863.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='status', y=col, data=df, palette='pastel')

# %% [markdown]
# **Violin Plots**

# %%
plt.figure(figsize=(15,4))
for i, col in enumerate(['age', 'year', 'positive_nodes']):
    plt.subplot(1,3,i+1)
    sns.violinplot(x='status', y=col, data=df, palette='muted')
    plt.title(f'{col} by Survival Status (Violin Plot)')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3628173237.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='status', y=col, data=df, palette='muted')
# /tmp/ipython-input-3628173237.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='status', y=col, data=df, palette='muted')
# /tmp/ipython-input-3628173237.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='status', y=col, data=df, palette='muted')

# %% [markdown]
# **Correlation Analysis**

# %%
plt.figure(figsize=(6,4))
corr = df[['age','year','positive_nodes']].corr()
sns.heatmap(corr, annot=True, cmap='Blues')
plt.title('Correlation Heatmap')
plt.show()
